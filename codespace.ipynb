# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

tips = sns.load_dataset("tips")
df = pd.DataFrame(tips)

df['tip_pct'] = df['tip'] / df['total_bill'] * 100 # [[YOUR CODE]]
plt.hist(df['tip_pct'], bins=50) # [[YOUR CODE]]

plt.show()
